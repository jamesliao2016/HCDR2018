# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
# Read the data
df = pd.read_csv('/Users/jamesliao2018/Downloads/device_failure.csv',encoding="ISO-8859-1")

# %%
df.tail()
# Out:
#               date    device  failure  attribute1  attribute2  attribute3  \
# 124489  2015-11-02  Z1F0MA1S        0    18310224           0           0
# 124490  2015-11-02  Z1F0Q8RT        0   172556680          96         107
# 124491  2015-11-02  Z1F0QK05        0    19029120        4832           0
# 124492  2015-11-02  Z1F0QL3N        0   226953408           0           0
# 124493  2015-11-02  Z1F0QLC1        0    17572840           0           0
#
#         attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 124489           0          10      353705           8           8           0
# 124490           4          11      332792           0           0          13
# 124491           0          11      350410           0           0           0
# 124492           0          12      358980           0           0           0
# 124493           0          10      351431           0           0           0

# %%
df[df.failure==1].head()
# Out:
#              date    device  failure  attribute1  attribute2  attribute3  \
# 4885   2015-01-05  S1F0RRB1        1    48467332       64776           0
# 6879   2015-01-07  S1F0CTDN        1   184069720         528           0
# 8823   2015-01-09  W1F0PNA5        1   136429411       64784           0
# 11957  2015-01-13  W1F13SRV        1   188251248        2040           0
# 12668  2015-01-14  W1F1230J        1   220461296           0           0
#
#        attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 4885          841           8       39267          56          56           1
# 6879            4           9      387871          32          32           3
# 8823          406          30      224801           8           8           0
# 11957           0           6       39345          32          32           1
# 12668           0          14      325125           0           0           0

# %% [markdown]
# ###### Assuming that the date of each device appeared first is the starting date, we add the running days on each day as the new feature "length"

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df[df.device=='S1F01085']
# Out:
#            date    device  failure  attribute1  attribute2  attribute3  \
# 0    2015-01-01  S1F01085        0   215630672          56           0
# 1163 2015-01-02  S1F01085        0     1650864          56           0
# 2326 2015-01-03  S1F01085        0   124017368          56           0
# 3489 2015-01-04  S1F01085        0   128073224          56           0
# 4651 2015-01-05  S1F01085        0    97393448          56           0
# 5812 2015-01-06  S1F01085        0   128832128          56           0
#
#       attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 0             52           6      407438           0           0           7
# 1163          52           6      407438           0           0           7
# 2326          52           6      407438           0           0           7
# 3489          52           6      407439           0           0           7
# 4651          52           6      408114           0           0           7
# 5812          52           6      409404           0           0           7

# %%
df_device_start = df.groupby('device').date.min().reset_index()

# %%
df_device_start.head()
# Out:
#      device       date
# 0  S1F01085 2015-01-01
# 1  S1F013BB 2015-05-06
# 2  S1F0166B 2015-01-01
# 3  S1F01E6Y 2015-01-01
# 4  S1F01JE0 2015-01-01

# %%
df_device_start = df_device_start.merge(df,on=['device','date'],how='left')

# %%
df_device_start.columns
# Out:
# Index(['device', 'date', 'failure', 'attribute1', 'attribute2', 'attribute3',
#        'attribute4', 'attribute5', 'attribute6', 'attribute7', 'attribute8',
#        'attribute9'],
#       dtype='object')

# %%
list_feat = df_device_start.columns[1:]

# %%
dict_feat = {}

# %%
for i in list_feat:
    if i not in dict_feat:
        dict_feat[i] = i+'_start'

# %%
df_device_start = df_device_start.rename(columns=dict_feat)

# %%
df_device_start.head()
# Out:
#      device date_start  failure_start  attribute1_start  attribute2_start  \
# 0  S1F01085 2015-01-01              0         215630672                56
# 1  S1F013BB 2015-05-06              0          14533968                 0
# 2  S1F0166B 2015-01-01              0          61370680                 0
# 3  S1F01E6Y 2015-01-01              0         173295968                 0
# 4  S1F01JE0 2015-01-01              0          79694024                 0
#
#    attribute3_start  attribute4_start  attribute5_start  attribute6_start  \
# 0                 0                52                 6            407438
# 1                 0                 0                 5            688952
# 2                 3                 0                 6            403174
# 3                 0                 0                12            237394
# 4                 0                 0                 6            410186
#
#    attribute7_start  attribute8_start  attribute9_start
# 0                 0                 0                 7
# 1                 0                 0                 0
# 2                 0                 0                 0
# 3                 0                 0                 0
# 4                 0                 0                 0

# %%
df_device_start.failure_start.value_counts()
# Out:
# 0    1169
# Name: failure_start, dtype: int64

# %%
df = df_device_start.merge(df,on=['device'],how='left')

# %%
df.head()
# Out:
#      device date_start  failure_start  attribute1_start  attribute2_start  \
# 0  S1F01085 2015-01-01              0         215630672                56
# 1  S1F01085 2015-01-01              0         215630672                56
# 2  S1F01085 2015-01-01              0         215630672                56
# 3  S1F01085 2015-01-01              0         215630672                56
# 4  S1F01085 2015-01-01              0         215630672                56
#
#    attribute3_start  attribute4_start  attribute5_start  attribute6_start  \
# 0                 0                52                 6            407438
# 1                 0                52                 6            407438
# 2                 0                52                 6            407438
# 3                 0                52                 6            407438
# 4                 0                52                 6            407438
#
#    attribute7_start     ...      failure  attribute1 attribute2  attribute3  \
# 0                 0     ...            0   215630672         56           0
# 1                 0     ...            0     1650864         56           0
# 2                 0     ...            0   124017368         56           0
# 3                 0     ...            0   128073224         56           0
# 4                 0     ...            0    97393448         56           0
#
#    attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 0          52           6      407438           0           0           7
# 1          52           6      407438           0           0           7
# 2          52           6      407438           0           0           7
# 3          52           6      407439           0           0           7
# 4          52           6      408114           0           0           7
#
# [5 rows x 23 columns]

# %%
df[df.device=='S1F0CTDN'].to_csv('sample_device_0624.csv')

# %%
df['device_head']=df['device'].apply(lambda x:x[:2])

# %%
df.device_head.value_counts()
# Out:
# S1    54858
# W1    43268
# Z1    26368
# Name: device_head, dtype: int64

# %%
df['device_mid']=df['device'].apply(lambda x:x[2:4])

# %%
df.device_mid.value_counts()
# Out:
# F0    75332
# F1    48911
# F2      251
# Name: device_mid, dtype: int64

# %%
df['device_last']=df['device'].apply(lambda x:x[4:])

# %%
df.device_last.value_counts()
# Out:
# JY02    304
# KJDS    304
# 5X69    304
# JXDL    304
# MA1S    304
# FGBQ    304
# QK05    304
# QLC1    304
# GB8A    304
# G9T7    304
# QL3N    304
# FZPA    304
# KKN4    304
# GPXY    304
# Q8RT    304
# H6JG    304
# FEH7    304
# GE1M    304
# SJJ2    304
# GGPP    304
# E9EP    304
# FY92    304
# KYCR    304
# JH87    304
# GCED    304
# FP0C    304
# EGMT    304
# T0B1    299
# 3432    295
# 1SL0    295
#        ...
# BN0S      5
# CT09      5
# 8R94      5
# CSRZ      5
# NTWG      5
# 3RV3      5
# 5P5Z      5
# L55E      5
# CJKT      5
# 4F5V      5
# 19X9      5
# CWXJ      5
# CHZK      5
# BJ6E      5
# CTRL      5
# LR8G      5
# LL2X      5
# KDDQ      5
# CTDY      5
# 1FCC      5
# 4GWF      5
# H9RN      5
# 0QH3      5
# 51C1      5
# L7NS      5
# A0CJ      5
# LQDQ      5
# 4KSC      4
# WJFT      3
# DA5ÿ      1
# Name: device_last, Length: 1169, dtype: int64

# %%
df[df.device_last=='KJDS'].device.unique()
# Out:
# array(['Z1F0KJDS'], dtype=object)

# %%
df[df.device_mid=='F1'].device.unique()
# Out:
# array(['S1F100R5', 'S1F101MC', 'S1F101SP', 'S1F1021H', 'S1F102L8',
#        'S1F1073Z', 'S1F10AS0', 'S1F10BNL', 'S1F10BRH', 'S1F10D0P',
#        'S1F10E6M', 'S1F10EBC', 'S1F10FDX', 'S1F10FF0', 'S1F10FFZ',
#        'S1F10FZB', 'S1F10GDQ', 'S1F10GSG', 'S1F10HH5', 'S1F10JL3',
#        'S1F10NDB', 'S1F10NM6', 'S1F10P0S', 'S1F10PED', 'S1F10QDG',
#        'S1F10QG6', 'S1F10QH3', 'S1F10QL8', 'S1F10RKC', 'S1F10RWZ',
#        'S1F10V1N', 'S1F10VJH', 'S1F10VP8', 'S1F114QM', 'S1F114QR',
#        'S1F115Z6', 'S1F1162D', 'S1F116H4', 'S1F116J4', 'S1F117PK',
#        'S1F118JP', 'S1F119X9', 'S1F11A9R', 'S1F11AK8', 'S1F11AXR',
#        'S1F11B1E', 'S1F11C16', 'S1F11CJC', 'S1F11DBJ', 'S1F11ETS',
#        'S1F11G2C', 'S1F11GG5', 'S1F11K34', 'S1F11KAY', 'S1F11KQW',
#        'S1F11L11', 'S1F11MB0', 'S1F11MT9', 'S1F11S2Q', 'S1F11S5B',
#        'S1F11WEH', 'S1F11XDA', 'S1F11Y4K', 'S1F11YHR', 'S1F121LH',
#        'S1F122HQ', 'S1F122KD', 'S1F12788', 'S1F12XGM', 'S1F12XJ4',
#        'S1F12Y53', 'S1F12ZAS', 'S1F12ZQB', 'S1F12ZQN', 'S1F12ZRR',
#        'S1F12ZSD', 'S1F12ZZ2', 'S1F130GX', 'S1F130JB', 'S1F1318D',
#        'S1F131F6', 'S1F1327G', 'S1F132A5', 'S1F133YJ', 'S1F13432',
#        'S1F134QM', 'S1F13589', 'S1F1358N', 'S1F1359T', 'S1F135BR',
#        'S1F135CE', 'S1F135D3', 'S1F135DG', 'S1F135DN', 'S1F135F0',
#        'S1F135F2', 'S1F135F3', 'S1F135GA', 'S1F135QH', 'S1F135SZ',
#        'S1F135TN', 'S1F135WP', 'S1F1360P', 'S1F1360W', 'S1F13619',
#        'S1F13635', 'S1F1364P', 'S1F1365W', 'S1F1368E', 'S1F13699',
#        'S1F136A5', 'S1F136BS', 'S1F136FG', 'S1F136J0', 'S1F136JY',
#        'S1F136KG', 'S1F136KJ', 'S1F13B32', 'S1F13BQX', 'S1F13BTN',
#        'S1F13CBB', 'S1F13CMG', 'S1F13GPY', 'S1F13H80', 'S1F13HPP',
#        'S1F13HPR', 'S1F13HWA', 'S1F13JW4', 'S1F13K7S', 'S1F13K8E',
#        'S1F13KBJ', 'S1F13KBZ', 'S1F13KC2', 'S1F13KF6', 'S1F13KG3',
#        'S1F13KNV', 'S1F13KZK', 'S1F13M9A', 'S1F13MAM', 'W1F10Y8K',
#        'W1F111C6', 'W1F111N7', 'W1F111Q7', 'W1F11CR1', 'W1F11FCC',
#        'W1F11JQW', 'W1F11ZG9', 'W1F1230J', 'W1F12JLS', 'W1F12JRF',
#        'W1F12KWT', 'W1F1335J', 'W1F133A0', 'W1F1354W', 'W1F13B09',
#        'W1F13SJ7', 'W1F13SRV', 'W1F14FS4', 'W1F14GTK', 'W1F14GWF',
#        'W1F14H94', 'W1F14HAQ', 'W1F14N6K', 'W1F14NBM', 'W1F14NE5',
#        'W1F14XGD', 'W1F14XK6', 'W1F15NRT', 'W1F15P5S', 'W1F15S4D',
#        'W1F16RA7', 'W1F17D9Z', 'W1F17DKS', 'W1F17E35', 'W1F17GR6',
#        'W1F17RLV', 'W1F181WP', 'W1F18TKX', 'W1F18YT8', 'W1F19BPT',
#        'W1F19J5Q', 'W1F19LPJ', 'W1F1A4H9', 'W1F1AN6A', 'W1F1AQ6G',
#        'W1F1ARYY', 'W1F1B0KF', 'W1F1BAE6', 'W1F1BFHS', 'W1F1BFMS',
#        'W1F1BFP5', 'W1F1BFRJ', 'W1F1BFZT', 'W1F1BG0P', 'W1F1BG4H',
#        'W1F1BGAB', 'W1F1BQNS', 'W1F1BQTN', 'W1F1BRM3', 'W1F1BS0H',
#        'W1F1BS9T', 'W1F1BTB2', 'W1F1BW8W', 'W1F1BZTM', 'W1F1C0R9',
#        'W1F1C51R', 'W1F1C9HM', 'W1F1C9TE', 'W1F1C9WG', 'W1F1CA72',
#        'W1F1CAKS', 'W1F1CB5E', 'W1F1CCGF', 'W1F1CDDP', 'W1F1CDRE',
#        'W1F1CHY9', 'W1F1CHZK', 'W1F1CJ1K', 'W1F1CJ27', 'W1F1CJ3G',
#        'W1F1CJKT', 'W1F1CJXM', 'W1F1CK1V', 'W1F1CK5G', 'W1F1CKB5',
#        'W1F1CKJZ', 'W1F1CKKW', 'W1F1CKSX', 'W1F1CKXZ', 'W1F1CL1K',
#        'W1F1CL8Q', 'W1F1CLBY', 'W1F1CLED', 'W1F1CLH3', 'W1F1CLJG',
#        'W1F1CLNF', 'W1F1CM57', 'W1F1CM7H', 'W1F1CM93', 'W1F1CMCY',
#        'W1F1CMFD', 'W1F1CMG4', 'W1F1CMJW', 'W1F1CMVG', 'W1F1CMVW',
#        'W1F1CNV3', 'W1F1CZLY', 'W1F1D899', 'W1F1D8GZ', 'W1F1D93M',
#        'W1F1D99S', 'W1F1DA55', 'W1F1DA5ÿ', 'W1F1DABR', 'W1F1DN0Y',
#        'W1F1DN3S', 'W1F1DNYH', 'W1F1DPSA', 'W1F1DQ6A', 'W1F1DQJD',
#        'W1F1DQN8', 'W1F1DQQT', 'W1F1DQR9', 'W1F1DX8D', 'W1F1FHEK',
#        'W1F1FZ8B', 'W1F1GLFN', 'W1F1GMWX', 'W1F1MRP9', 'W1F1MTM2',
#        'W1F1N4CT', 'W1F1N6V6', 'W1F1NS0C', 'W1F1NSHB', 'W1F1NTWG',
#        'W1F1Q5EF', 'W1F1ZVME', 'Z1F118C9', 'Z1F11B2R', 'Z1F11BHF',
#        'Z1F11RAE', 'Z1F11SL0', 'Z1F11SYE', 'Z1F130LH', 'Z1F1473X',
#        'Z1F1479Y', 'Z1F147WQ', 'Z1F148T1', 'Z1F14BGY', 'Z1F14F5V',
#        'Z1F14Z4F', 'Z1F151C1', 'Z1F156MQ', 'Z1F15HYM', 'Z1F15VY4',
#        'Z1F161QC', 'Z1F1632F', 'Z1F1652D', 'Z1F1653X', 'Z1F16BR1',
#        'Z1F16G31', 'Z1F16LDN', 'Z1F17XPD', 'Z1F17YTD', 'Z1F17Z3N',
#        'Z1F17ZCN', 'Z1F18YB3', 'Z1F18YST', 'Z1F1901P', 'Z1F19ENW',
#        'Z1F19KMH', 'Z1F19QH0', 'Z1F19QM3', 'Z1F19TP2', 'Z1F19TVX',
#        'Z1F19VF5', 'Z1F1A0CJ', 'Z1F1A0LM', 'Z1F1A0RP', 'Z1F1A1HH',
#        'Z1F1A7MG', 'Z1F1A83K', 'Z1F1AD0M', 'Z1F1AF54', 'Z1F1AFF2',
#        'Z1F1AFT5', 'Z1F1AG5N', 'Z1F1AGLA', 'Z1F1AGN5', 'Z1F1AGW1',
#        'Z1F1B6H4', 'Z1F1B6NP', 'Z1F1B799', 'Z1F1CZ35', 'Z1F1FCH5',
#        'Z1F1FZ9J', 'Z1F1HEQR', 'Z1F1HSWK', 'Z1F1Q9BD', 'Z1F1R76A',
#        'Z1F1RE71', 'Z1F1RJFA', 'Z1F1VMZB', 'Z1F1VQFY'], dtype=object)

# %%
df['length'] = df['date']-df['date_start']

# %%
df['length'] = df['length'].dt.days

# %%
df.head()
# Out:
#      device date_start       date  failure  attribute1  attribute2  \
# 0  S1F01085 2015-01-01 2015-01-01        0   215630672          56
# 1  S1F01085 2015-01-01 2015-01-02        0     1650864          56
# 2  S1F01085 2015-01-01 2015-01-03        0   124017368          56
# 3  S1F01085 2015-01-01 2015-01-04        0   128073224          56
# 4  S1F01085 2015-01-01 2015-01-05        0    97393448          56
#
#    attribute3  attribute4  attribute5  attribute6  attribute7  attribute8  \
# 0           0          52           6      407438           0           0
# 1           0          52           6      407438           0           0
# 2           0          52           6      407438           0           0
# 3           0          52           6      407439           0           0
# 4           0          52           6      408114           0           0
#
#    attribute9  length
# 0           7       0
# 1           7       1
# 2           7       2
# 3           7       3
# 4           7       4

# %%
for col in [0,1]:
    sns.kdeplot(df[df.failure==col]['length'], shade=True,label = col)

# %%
sns.distplot(df[df.failure==0]['length'])

# %%
sns.distplot(df[df.failure==1]['length']);
